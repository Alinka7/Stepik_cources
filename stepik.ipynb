# %%
import pandas as pd 
import numpy as np

# %%
StudentsPerfomance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
StudentsPerfomance = pd.read_csv('C:/Users/User1/Desktop/steplk/StudentsPerformance.csv')

# %%
StudentsPerfomance.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
StudentsPerfomance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
StudentsPerfomance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
StudentsPerfomance.shape
# Out:
# (1000, 8)

# %%
StudentsPerfomance.groupby('gender').aggregate({'writing score' : 'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
StudentsPerfomance.size
# Out:
# 8000

# %%
StudentsPerfomance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
StudentsPerfomance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
StudentsPerfomance. iloc[0:5, 0:5]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course
# 0                    none
# 1               completed
# 2                    none
# 3                    none
# 4                    none

# %%
StudentsPerfomance.iloc[[1,6,9,26], [1,5,-1]]
# Out:
#    race/ethnicity  math score  writing score
# 1         group C          69             88
# 6         group B          88             92
# 9         group B          38             50
# 26        group B          69             55

# %%
Set1 = StudentsPerfomance.iloc[[3,5,7,9,4]]

# %%
Set1.index = ['alina', ' maryna', ' dima', ' anton', 'mama']

# %%
Set1
# Out:
#          gender race/ethnicity parental level of education         lunch  \
# alina      male        group A          associate's degree  free/reduced
#  maryna  female        group B          associate's degree      standard
#  dima      male        group B                some college  free/reduced
#  anton   female        group B                 high school  free/reduced
# mama       male        group C                some college      standard
#
#         test preparation course  math score  reading score  writing score
# alina                      none          47             57             44
#  maryna                    none          71             83             78
#  dima                      none          40             43             39
#  anton                     none          38             60             50
# mama                       none          76             78             75

# %%
Set1.loc[['alina', 'dima'], :]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-eb808c50b40a> in <module>
# ----> 1 Set1.loc[['alina', 'dima'], :]
#
# D:\Users\User1\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# D:\Users\User1\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1286                 continue
#    1287
# -> 1288             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1289
#    1290         return retval
#
# D:\Users\User1\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
# ...

# %%
Set1.iloc[:, 0]

# %%
pd.Series([1,2,4,6], index = ['alina', 'dima', 'mam', 'ann'])
# Out:
# alina    1
# dima     2
# mam      4
# ann      6
# dtype: int64

# %%
series1 = pd.Series([1,4,5], index = ['a', 'b', 'c'])
series2 = pd.Series([1,2,3], index = ['a', 'b', 'c'])

# %%
pd.DataFrame({'column_name1': series1, 'columnn_name2': series2})
# Out:
#    column_name1  columnn_name2
# a             1              1
# b             4              2
# c             5              3

# %%
Set1[['gender']]
# Out:
#          gender
# alina      male
#  maryna  female
#  dima      male
#  anton   female
# mama       male

# %%
Set1['gender']
# Out:
# alina        male
#  maryna    female
#  dima        male
#  anton     female
# mama         male
# Name: gender, dtype: object

# %%
set2 = pd.read_csv('C:/Users/User1/Desktop/titanic.csv')

# %%
set2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
set2.loc[:7]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
StudentsPerfomance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
StudentsPerfomance.loc[StudentsPerfomance.gender == 'female', ['gender', 'lunch']]
# Out:
#      gender         lunch
# 0    female      standard
# 1    female      standard
# 2    female      standard
# 5    female      standard
# 6    female      standard
# ..      ...           ...
# 993  female  free/reduced
# 995  female      standard
# 997  female  free/reduced
# 998  female      standard
# 999  female  free/reduced
#
# [518 rows x 2 columns]

# %%
writing_score_mean = StudentsPerfomance['writing score'].mean()

# %%
StudentsPerfomance.loc[StudentsPerfomance['writing score'] > writing_score, ['writing score', 'gender']]
# Out:
#      writing score  gender
# 0               74  female
# 1               88  female
# 2               93  female
# 4               75    male
# 5               78  female
# ..             ...     ...
# 992             76  female
# 993             74  female
# 995             95  female
# 998             77  female
# 999             86  female
#
# [512 rows x 2 columns]

# %%
StudentsPerfomance.loc[StudentsPerfomance['writing score'] > writing_score_mean].head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 4    male        group C                some college  standard
# 5  female        group B          associate's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 4                    none          76             78             75
# 5                    none          71             83             78

# %%
query = (StudentsPerfomance['writing score'] > writing_score_mean) & (StudentsPerfomance.gender == 'female')

# %%
query
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998     True
# 999     True
# Length: 1000, dtype: bool

# %%
StudentsPerfomance.loc[query].head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 5                    none          71             83             78
# 6               completed          88             95             92

# %%
StudentsPerfomance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
lunch = StudentsPerfomance.lunch == 'free/reduced'

# %%
lunch1 = StudentsPerfomance.lunch == 'standard'

# %%
lunch1
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 995     True
# 996    False
# 997    False
# 998     True
# 999    False
# Name: lunch, Length: 1000, dtype: bool

# %%
і = StudentsPerfomance.loc[lunch]

# %%
і1 = StudentsPerfomance.loc[lunch1]

# %%
StudentsPerfomance['lunch'].str.contains('free/reduced').mean()
# Out:
# 0.355

# %%
#дисперися
StudentsPerfomance['lunch'].str.contains('free/reduced').var()
# Out:
# 0.22920420420420418

# %%
StudentsPerfomance['lunch'].str.contains('standard').var()
# Out:
# 0.22920420420420418

# %%
print(StudentsPerfomance['math score'].mean())
print(StudentsPerfomance['writing score'].mean())
print(StudentsPerfomance['reading score'].mean())
# Out:
# 66.089
# 68.054
# 69.169

# %%
і.describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
і1.describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
StudentsPerfomance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
StudentsPerfomance = StudentsPerfomance.rename(columns = {'parental level of education': 'parental_level_of_education',
'test preparation course' : 'test_preparation_course',
'math score': 'math_score',
'reading score': 'reading_score',
'writing score': 'writing_score'})

# %%
StudentsPerfomance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
StudentsPerfomance.loc[StudentsPerfomance.gender == 'male']
# Out:
#     gender race/ethnicity parental_level_of_education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 3                      none          47             57             44
# ...

# %%
StudentsPerfomance.query('writing_score > 70')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
StudentsPerfomance.query("lunch == 'standard' | writing_score > 50")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
writing_score = 30
StudentsPerfomance.query("writing_score > @writing_score")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
 StudentsPerfomance[['gender', 'lunch', 'math_score']].head()
# Out:
#    gender         lunch  math_score
# 0  female      standard          72
# 1  female      standard          69
# 2  female      standard          90
# 3    male  free/reduced          47
# 4    male      standard          76

# %%
score_column  = [i for i in list(StudentsPerfomance) if 'score' in i]

# %%
score_column
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
 StudentsPerfomance[score_column ].head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
StudentsPerfomance.filter(like = 'score')
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
#axis = 1 -- стовпчики, axis = 0 -- рядки
Set1.filter(like = 'm', axis = 0 )
# Out:
#          gender race/ethnicity parental level of education         lunch  \
#  maryna  female        group B          associate's degree      standard
#  dima      male        group B                some college  free/reduced
# mama       male        group C                some college      standard
#
#         test preparation course  math score  reading score  writing score
#  maryna                    none          71             83             78
#  dima                      none          40             43             39
# mama                       none          76             78             75

# %%
df = pd.read_csv('C:/Users/User1/Desktop/steplk/column_hell.csv')

# %%
df
# Out:
#        yrh&6      ohku         q      hfxx   umeca-4       apj         g  \
# 0   0.288397  0.911359  0.488069  0.074599  0.016124  0.090555  0.560810
# 1   0.861276  0.134987  0.701885  0.897921  0.507115  0.740151  0.963179
# 2   0.775577  0.832874  0.862665  0.831049  0.003274  0.703112  0.509795
# 3   0.857910  0.555818  0.598305  0.473988  0.784139  0.427963  0.725103
# 4   0.748652  0.451725  0.252619  0.584361  0.011265  0.051115  0.755444
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.665300  0.744322  0.377087  0.809735  0.220817  0.248306  0.131914
# 96  0.344394  0.182979  0.590196  0.483025  0.474131  0.031048  0.672095
# 97  0.694568  0.507591  0.328004  0.333993  0.091637  0.356788  0.541017
# 98  0.692840  0.220333  0.729843  0.202430  0.360106  0.980271  0.913669
# 99  0.391447  0.989147  0.011527  0.894302  0.669284  0.158220  0.283287
#
#     ijvnixxo  kudbpyw-3    upubjv  ...        fi   clsruyy       g&6  \
# ...

# %%
selected_columns = df.filter(like = '-')

# %%
selected_columns
# Out:
#      umeca-4  kudbpyw-3       g-3       v-9     fla-6  hwtbyrkp-5
# 0   0.016124   0.430787  0.202407  0.725508  0.305076    0.979296
# 1   0.507115   0.671662  0.864249  0.867818  0.358859    0.160520
# 2   0.003274   0.286411  0.928865  0.719159  0.340235    0.734612
# 3   0.784139   0.863717  0.175446  0.554744  0.049325    0.621132
# 4   0.011265   0.206172  0.044151  0.163643  0.048806    0.437836
# ..       ...        ...       ...       ...       ...         ...
# 95  0.220817   0.434444  0.601738  0.146333  0.918888    0.216499
# 96  0.474131   0.176011  0.359793  0.104707  0.257690    0.066934
# 97  0.091637   0.871606  0.121075  0.907699  0.313184    0.788592
# 98  0.360106   0.172385  0.015285  0.019571  0.060751    0.403166
# 99  0.669284   0.701505  0.481430  0.024944  0.644989    0.702003
#
# [100 rows x 6 columns]
