# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
StudentsPerformance = pd.read_csv('C:/Users/User1/Desktop/steplk/StudentsPerformance.csv')

# %%
StudentsPerformance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
StudentsPerformance = StudentsPerformance.rename(columns = {'parental level of education': 'parental_level_of_education',
'test preparation course':'test_preparation_course', 'math score': 'math_score', 'reading score':'reading_score','writing score' : 'writing_score' })

# %%
StudentsPerformance.math_score.hist()

# %%
StudentsPerformance.math_score.hist()

# %%
StudentsPerformance.plot()

# %%
StudentsPerformance.plot.scatter(x = 'math_score', y = 'reading_score')

# %%
#hue - групирующая переменная
#fit_reg = False - убрать регресеонную прямую
plot = sns.lmplot(x = 'math_score', y = 'reading_score', hue = 'gender', fit_reg = True, data = StudentsPerformance)
#названия оссей
plot.set_xlabels('Math scores')
plot.set_ylabels('Reading scores')

# %% [markdown]
# # Завдання

# %%
df = pd.read_csv('C:/Users/User1/Desktop/steplk/income.csv')

# %%
df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df.income.plot()

# %%
df1 = pd.read_csv('C:/Users/User1/Desktop/steplk/genome_matrix.csv')

# %%
df1
# Out:
#   Unnamed: 0  species0  species1  species2  species3  species4
# 0   species0  0.536029  0.920292  0.679708  0.840606  0.430842
# 1   species1  0.920292  0.862417  0.887593  0.769754  0.203214
# 2   species2  0.679708  0.887593  0.595156  0.003435  0.096052
# 3   species3  0.840606  0.769754  0.003435  0.458870  0.029251
# 4   species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
from numpy import genfromtxt
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set()
my_data = genfromtxt('C:/Users/User1/Desktop/steplk/genome_matrix.csv', delimiter=',')

# %%
g  = sns.heatmap(my_data, cmap = 'viridis')
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
df = pd.read_csv('C:/Users/User1/Desktop/steplk/dota_hero_stats.csv')

# %%
df
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
iris = pd.read_csv('C:/Users/User1/Desktop/steplk/iris.csv')

# %%
iris
# Out:
#      Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0             0           5.1          3.5           1.4          0.2        0
# 1             1           4.9          3.0           1.4          0.2        0
# 2             2           4.7          3.2           1.3          0.2        0
# 3             3           4.6          3.1           1.5          0.2        0
# 4             4           5.0          3.6           1.4          0.2        0
# ..          ...           ...          ...           ...          ...      ...
# 145         145           6.7          3.0           5.2          2.3        2
# 146         146           6.3          2.5           5.0          1.9        2
# 147         147           6.5          3.0           5.2          2.0        2
# 148         148           6.2          3.4           5.4          2.3        2
# 149         149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 6 columns]

# %%
sns.distplot(iris['sepal width']);

# %%
sns.kdeplot(iris['sepal length']);

# %%
sns.kdeplot(iris['petal length']);

# %%
sns.distplot(iris[['petal length','petal width']]);

# %%
iris
# Out:
#      Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0             0           5.1          3.5           1.4          0.2        0
# 1             1           4.9          3.0           1.4          0.2        0
# 2             2           4.7          3.2           1.3          0.2        0
# 3             3           4.6          3.1           1.5          0.2        0
# 4             4           5.0          3.6           1.4          0.2        0
# ..          ...           ...          ...           ...          ...      ...
# 145         145           6.7          3.0           5.2          2.3        2
# 146         146           6.3          2.5           5.0          1.9        2
# 147         147           6.5          3.0           5.2          2.0        2
# 148         148           6.2          3.4           5.4          2.3        2
# 149         149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 6 columns]

# %%
sns.violinplot(y = iris["petal length"])

# %%
sns.pairplot(iris, hue = 'species')
